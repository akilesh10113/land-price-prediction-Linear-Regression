# %%
### *Import Libraries*

import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
## *Load Dataset

dataset = pd.read_csv("/Users/akileshsenthilkumar/Documents/practice/Machine Learning/Regression/Linear Regression/dataset.csv")

# %%
## Summarrize

print(dataset.shape)
print(dataset.head(5))
# Out:
# (1460, 2)
#     area   price
# 0   8450  208500
# 1   9600  181500
# 2  11250  223500
# 3   9550  140000
# 4  14260  250000

# %%
# *Visualize Dataset*

plt.xlabel('Area')
plt.ylabel('Price')
plt.scatter(dataset.area,dataset.price,color = 'blue', marker= '+' )

# %%
### *Segregate Dataset into Input X & Output Y

x = dataset.drop('price',axis = 'columns')
print(x)
# Out:
#        area
# 0      8450
# 1      9600
# 2     11250
# 3      9550
# 4     14260
# ...     ...
# 1455   7917
# 1456  13175
# 1457   9042
# 1458   9717
# 1459   9937
#
# [1460 rows x 1 columns]

# %%
y = dataset.price
y
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: price, Length: 1460, dtype: int64

# %%
### *Training Dataset using Linear Regression*""

model = LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
### *Predicted Price for Land sq.Feet of custom values*"""

x = int(input("enter the value"))
LandAreainSqFt = [[x]]
PredictedmodelResult = model.predict(LandAreainSqFt)
print(PredictedmodelResult)
# Out:
# enter the value 300000
# [788827.73740918]
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
### Theory Calculation
## *Coefficient - m*

m = model.coef_
print(m)
# Out:
# [2.09997195]

# %%
## *Intercept - b

b =model.intercept_
print(b)
# Out:
# 158836.15189687657

# %%
## Y=mx+b

y = m*x + b
print("The Price of {0} square feet Land is: {1}" . format(x,y[0]))
# Out:
# The Price of 300000 square feet Land is: 788827.7374091796
